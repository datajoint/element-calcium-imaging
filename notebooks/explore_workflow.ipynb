# %% [markdown]
# # DataJoint U24 Workflow Imaging
# This notebook will describe the steps for interacting with the data ingested into `workflow-imaging`.
#
# Prior to using this notebook, please refer to the [README](https://github.com/datajoint/workflow-imaging) for the topics listed below.
#     + Installation instructions
#     + Directory structure and file naming convention
#     + Running the workflow

# %%
import os
os.chdir('..')
from workflow_imaging.pipeline import *

# %% [markdown]
# ## Workflow architecture

# %%
dj.Diagram(lab)

# %%
dj.Diagram(subject)

# %%
dj.Diagram(scan)

# %%
dj.Diagram(imaging)

# %%
subject.Subject()

# %%
Session()

# %%
scan.ScanInfo()

# %%
scan.ScanInfo.Field()

# %%
imaging.ProcessingParamSet()

# %%
imaging.ProcessingTask()
